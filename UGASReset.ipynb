# %% [markdown]
# <a href="https://colab.research.google.com/github/juanindicopleustes-ops/Spectral-Stability-Reset-Systems/blob/main/UGASReset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Crear estructura de carpetas
os.makedirs('src', exist_ok=True)
os.makedirs('data/output', exist_ok=True)

# %%
import sys
sys.path.append('/content/src')

# Ejecutar el script de recomputación
# !python src/recompute_table1_fullmap.py
# Out:
# --- Recomputing Table 1 from the full state-dependent return map ---
#
# tau_m = 0.10
#   cocycle estimate  : 0.386202 (horizon = 100, best theta0 = 2.002242, log-average = -0.951394)
#   EDMD estimate     : 0.365488 (matrix size = 25, samples = 12600)
#   regular branch    : 0.818731
#
# tau_m = 0.20
#   cocycle estimate  : 0.381213 (horizon = 100, best theta0 = 5.449616, log-average = -0.964396)
#   EDMD estimate     : 0.348121 (matrix size = 25, samples = 12600)
#   regular branch    : 0.670320
#
# tau_m = 0.40
#   cocycle estimate  : 0.362195 (horizon = 100, best theta0 = 4.329115, log-average = -1.015573)
#   EDMD estimate     : 0.331757 (matrix size = 25, samples = 12600)
#   regular branch    : 0.449329
#
# tau_m = 0.60
#   cocycle estimate  : 0.370159 (horizon = 100, best theta0 = 1.874484, log-average = -0.993822)
#   EDMD estimate     : 0.328717 (matrix size = 25, samples = 12600)
#   regular branch    : 0.301194
#
# tau_m = 0.80
# ...

# %%
# !python src/plot_figure1_from_recomputed.py
# Out:
# Saved PDF figure to: /content/data/output/figure1_full_benchmark_recomputed.pdf
# Saved PNG figure to: /content/data/output/figure1_full_benchmark_recomputed.png
# Figure(660x440)

# %%
from google.colab import files

# Descargar el PDF para LaTeX y el CSV de datos originales
files.download('/content/data/output/figure1_full_benchmark_recomputed.pdf')
files.download('/content/data/output/table1_results_recomputed.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
